# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Summarizing, Aggregating & Grouping
# Knowing how to use pandas aggregation & grouping functions lets us reduce the dimensionality of our data and visualize it in different ways (most often over the rows - aka `axis=0`).
#
# For completeness, `axis=1` refers to the columns.

# %%
wine = pd.read_csv('data/wine_reviews/winemag-data_first150k.csv', index_col=0)

# %% [markdown]
# Answer to exercise from notebook 1:
#
#
# `scrambled_wine[['points', 'region_1']].iloc[:5]
# `

# %% [markdown]
# ## Initial quick analysis using pandas
# Pandas has multiple built-in functions that make it easy to quickly see what's in your dataframe.
# You can build them with the selecting tools you used before.

# %% [markdown]
# Here, we will select a column, and then see how pandas lets us quickly analyse it.
#
# To quickly see which columns our wine dataset has, we can use the .columns attribute.

# %%
# print("Average wine price: ", round(wine_price.mean(), 2)
wine.head(50)
# Out:
#         country                                        description  \
# 0            US  This tremendous 100% varietal wine hails from ...
# 1         Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            US  Mac Watson honors the memory of a wine once ma...
# 3            US  This spent 20 months in 30% new French oak, an...
# 4        France  This is the top wine from La Bégude, named aft...
# 5         Spain  Deep, dense and pure from the opening bell, th...
# 6         Spain  Slightly gritty black-fruit aromas include a s...
# 7         Spain  Lush cedary black-fruit aromas are luxe and of...
# 8            US  This re-named vineyard was formerly bottled as...
# 9            US  The producer sources from two blocks of the vi...
# 10        Italy  Elegance, complexity and structure come togeth...
# 11           US  From 18-year-old vines, this supple well-balan...
# 12           US  A standout even in this terrific lineup of 201...
# 13       France  This wine is in peak condition. The tannins an...
# 14           US  With its sophisticated mix of mineral, acid an...
# 15           US  First made in 2006, this succulent luscious Ch...
# 16           US  This blockbuster, powerhouse of a wine suggest...
# 17        Spain  Nicely oaked blackberry, licorice, vanilla and...
# 18       France  Coming from a seven-acre vineyard named after ...
# 19           US  This fresh and lively medium-bodied wine is be...
# 20           US  Heitz has made this stellar rosé from the rare...
# 21        Spain  Alluring, complex and powerful aromas of grill...
# 22        Spain  Tarry blackberry and cheesy oak aromas are app...
# 23           US  The apogee of this ambitious winery's white wi...
# 24           US  San Jose-based producer Adam Comartin heads 1,...
# 25  New Zealand  Yields were down in 2015, but intensity is up,...
# 26           US  Bergström has made a Shea designate since 2003...
# 27           US  Focused and dense, this intense wine captures ...
# 28           US  Cranberry, baked rhubarb, anise and crushed sl...
# 29           US  This standout Rocks District wine brings earth...
# 30     Bulgaria  This Bulgarian Mavrud presents the nose with s...
# 31           US  Steely and perfumed, this wine sees only 20% n...
# 32        Italy  Underbrush, scorched earth, menthol and plum s...
# 33       France  Pale in color, this is nutty in character, wit...
# 34           US  The aromas entice with notes of wet stone, hon...
# 35        Italy  Forest floor, tilled soil, mature berry and a ...
# 36       France  Gingery spice notes accent fresh pear and melo...
# 37        Italy  Aromas of forest floor, violet, red berry and ...
# 38        Italy  This has a charming nose that boasts rose, vio...
# 39        Italy  This bright, savory wine delivers aromas and f...
# 40        Spain  Earthy plum and cherry aromas score points for...
# 41        Spain  This comes across wide and expansive as it laz...
# 42           US  This is an aromatic brooder with aromas of sco...
# 43        Italy  Aromas of dark-skinned berry, rose and wild he...
# 44       France  Dark in color and in flavor profile, this medi...
# 45        Italy  A blend of 90% Sangiovese and 10% Canaiolo, th...
# 46        Italy  Sunbaked earth, ripe berry, baking spice and a...
# 47           US  Blended with 9% Malbec, 9% Cabernet Franc and ...
# 48        Italy  Ripe dark-skinned berry, forest floor and cook...
# 49           US  The aromas of blue fruit, herbs and spice are ...
#
#                              designation  points  price            province  \
# 0                      Martha's Vineyard      96  235.0          California
# 1   Carodorum Selección Especial Reserva      96  110.0      Northern Spain
# 2          Special Selected Late Harvest      96   90.0          California
# 3                                Reserve      96   65.0              Oregon
# 4                             La Brûlade      95   66.0            Provence
# 5                              Numanthia      95   73.0      Northern Spain
# 6                              San Román      95   65.0      Northern Spain
# 7                Carodorum Único Crianza      95  110.0      Northern Spain
# 8                                 Silice      95   65.0              Oregon
# 9                   Gap's Crown Vineyard      95   60.0          California
# 10                    Ronco della Chiesa      95   80.0  Northeastern Italy
# 11       Estate Vineyard Wadensvil Block      95   48.0              Oregon
# 12                        Weber Vineyard      95   48.0              Oregon
# 13               Château Montus Prestige      95   90.0    Southwest France
# 14                        Grace Vineyard      95  185.0              Oregon
# 15                                Sigrid      95   90.0              Oregon
# 16                       Rainin Vineyard      95  325.0          California
# 17                6 Años Reserva Premium      95   80.0      Northern Spain
# 18                         Le Pigeonnier      95  290.0    Southwest France
# 19                  Gap's Crown Vineyard      95   75.0          California
# 20                            Grignolino      95   24.0          California
# 21               Prado Enea Gran Reserva      95   79.0      Northern Spain
# 22                            Termanthia      95  220.0      Northern Spain
# 23                         Giallo Solare      95   60.0          California
# 24                         R-Bar-R Ranch      95   45.0          California
# 25                       Maté's Vineyard      94   57.0               Kumeu
# 26                         Shea Vineyard      94   62.0              Oregon
# 27                               Abetina      94  105.0              Oregon
# 28                       Garys' Vineyard      94   60.0          California
# 29                       The Funk Estate      94   60.0          Washington
# 30                               Bergulé      90   15.0            Bulgaria
# 31                              Babushka      90   37.0          California
# 32                         Vigna Piaggia      90    NaN             Tuscany
# 33            Nonpareil Trésor Rosé Brut      90   22.0        France Other
# 34                   Conner Lee Vineyard      90   42.0          Washington
# 35                               Riserva      90  135.0             Tuscany
# 36                                   NaN      90   60.0        Rhône Valley
# 37                                   NaN      90   29.0             Tuscany
# 38                                   NaN      90   23.0             Tuscany
# 39                               Riserva      90   29.0             Tuscany
# 40                                Amandi      90   17.0             Galicia
# 41                  Alfonso Oloroso Seco      90   26.0           Andalucia
# 42                       Private Reserve      90   55.0               Idaho
# 43                               Riserva      90   39.0             Tuscany
# 44                               Coteaux      90   69.0        Rhône Valley
# 45       Vigneto Odoardo Beccari Riserva      90   30.0             Tuscany
# 46                      Poggio alle Mura      90   90.0             Tuscany
# 47                          Estate Grown      90   60.0          California
# 48                                   NaN      90   50.0             Tuscany
# 49                                   NaN      90   40.0          Washington
#
#                         region_1           region_2                  variety  \
# 0                    Napa Valley               Napa       Cabernet Sauvignon
# 1                           Toro                NaN            Tinta de Toro
# 2                 Knights Valley             Sonoma          Sauvignon Blanc
# 3              Willamette Valley  Willamette Valley               Pinot Noir
# 4                         Bandol                NaN       Provence red blend
# 5                           Toro                NaN            Tinta de Toro
# 6                           Toro                NaN            Tinta de Toro
# 7                           Toro                NaN            Tinta de Toro
# 8             Chehalem Mountains  Willamette Valley               Pinot Noir
# 9                   Sonoma Coast             Sonoma               Pinot Noir
# 10                        Collio                NaN                 Friulano
# 11                  Ribbon Ridge  Willamette Valley               Pinot Noir
# 12                  Dundee Hills  Willamette Valley               Pinot Noir
# 13                       Madiran                NaN                   Tannat
# 14                  Dundee Hills  Willamette Valley               Pinot Noir
# 15             Willamette Valley  Willamette Valley               Chardonnay
# 16     Diamond Mountain District               Napa       Cabernet Sauvignon
# 17              Ribera del Duero                NaN              Tempranillo
# 18                        Cahors                NaN                   Malbec
# 19                  Sonoma Coast             Sonoma               Pinot Noir
# 20                   Napa Valley               Napa                     Rosé
# 21                         Rioja                NaN        Tempranillo Blend
# 22                          Toro                NaN            Tinta de Toro
# 23                   Edna Valley      Central Coast               Chardonnay
# 24          Santa Cruz Mountains      Central Coast               Pinot Noir
# 25                           NaN                NaN               Chardonnay
# 26             Willamette Valley                NaN               Pinot Noir
# 27             Willamette Valley  Willamette Valley               Pinot Noir
# 28         Santa Lucia Highlands      Central Coast               Pinot Noir
# 29       Walla Walla Valley (WA)    Columbia Valley                    Syrah
# 30                           NaN                NaN                   Mavrud
# 31          Russian River Valley             Sonoma               Chardonnay
# 32        Brunello di Montalcino                NaN               Sangiovese
# 33                  Vin Mousseux                NaN          Sparkling Blend
# 34          Columbia Valley (WA)    Columbia Valley               Chardonnay
# 35        Brunello di Montalcino                NaN               Sangiovese
# 36           Châteauneuf-du-Pape                NaN  Rhône-style White Blend
# 37  Vino Nobile di Montepulciano                NaN               Sangiovese
# 38              Chianti Classico                NaN               Sangiovese
# 39              Chianti Classico                NaN                Red Blend
# 40                 Ribeira Sacra                NaN                   Mencía
# 41                         Jerez                NaN                 Palomino
# 42                           NaN                NaN             Petite Sirah
# 43              Chianti Classico                NaN                Red Blend
# 44                        Cornas                NaN                    Syrah
# 45              Chianti Classico                NaN                Red Blend
# 46        Brunello di Montalcino                NaN               Sangiovese
# 47                  Mount Veeder               Napa       Cabernet Sauvignon
# 48        Brunello di Montalcino                NaN               Sangiovese
# 49                  Red Mountain    Columbia Valley       Cabernet Sauvignon
#
#                           winery
# 0                          Heitz
# 1        Bodega Carmen Rodríguez
# 2                       Macauley
# 3                          Ponzi
# 4           Domaine de la Bégude
# 5                      Numanthia
# 6                       Maurodos
# 7        Bodega Carmen Rodríguez
# 8                      Bergström
# 9                      Blue Farm
# 10              Borgo del Tiglio
# 11        Patricia Green Cellars
# 12        Patricia Green Cellars
# 13             Vignobles Brumont
# 14                Domaine Serene
# 15                     Bergström
# 16                          Hall
# 17                      Valduero
# 18            Château Lagrézette
# 19                  Gary Farrell
# 20                         Heitz
# 21                          Muga
# 22                     Numanthia
# 23              Center of Effort
# 24                      Comartin
# 25                   Kumeu River
# 26                     Bergström
# 27                         Ponzi
# 28                          Roar
# 29                        Saviah
# 30                  Villa Melnik
# 31                      Zepaltas
# 32               Abbadia Ardenga
# 33                Bouvet-Ladubay
# 34                          Buty
# 35                      Carillon
# 36  Clos de L'Oratoire des Papes
# 37                    Avignonesi
# 38              Casina di Cornia
# 39      Castello di Monterinaldi
# 40                Don Bernardino
# 41                González Byass
# 42                        Huston
# 43                       Rignana
# 44               Tardieu-Laurent
# 45                  Vignavecchia
# 46                         Banfi
# 47                      Brandlin
# 48            Brunelli Martoccia
# 49                    Canvasback

# %% [markdown]
# Let's select price.

# %% [markdown]
# We can quickly see some metrics of the price, using some built-in aggregating functions in pandas.

# %% [markdown]
# And some more advanced metrics..

# %%
wine.loc[:, 'country'].value_counts(ascending=False).sort_index()
# Out:
# Albania                       2
# Argentina                  5631
# Australia                  4957
# Austria                    3057
# Bosnia and Herzegovina        4
# Brazil                       25
# Bulgaria                     77
# Canada                      196
# Chile                      5816
# China                         3
# Croatia                      89
# Cyprus                       31
# Czech Republic                6
# Egypt                         3
# England                       9
# France                    21098
# Georgia                      43
# Germany                    2452
# Greece                      884
# Hungary                     231
# India                         8
# Israel                      630
# Italy                     23478
# Japan                         2
# Lebanon                      37
# Lithuania                     8
# Luxembourg                    9
# Macedonia                    16
# Mexico                       63
# Moldova                      71
# Montenegro                    2
# Morocco                      12
# New Zealand                3320
# Portugal                   5322
# Romania                     139
# Serbia                       14
# Slovakia                      3
# Slovenia                     94
# South Africa               2258
# South Korea                   4
# Spain                      8268
# Switzerland                   4
# Tunisia                       2
# Turkey                       52
# US                        62397
# US-France                     1
# Ukraine                       5
# Uruguay                      92
# Name: country, dtype: int64

# %% [markdown]
# What if we want to see this list in the opposite order?

# %%
wine.loc[:, "country"].count()
# Out:
# 150925

# %% [markdown]
# Both of these lists are too long. What if we only want to see the top 10 countries?
# We can string together the other selectors we learned before!
#
# Can you think of another way to get the top 10 rows?

# %%
wine.loc[:, 'country'].value_counts().head(10)
# Out:
# US             62397
# Italy          23478
# France         21098
# Spain           8268
# Chile           5816
# Argentina       5631
# Portugal        5322
# Australia       4957
# New Zealand     3320
# Austria         3057
# Name: country, dtype: int64

# %% [markdown]
# What if we just want to know how many countries are on the list?

# %%
# Number of non-null unique values
wine.loc[:, 'country'].nunique()
# Out:
# 48

# %% [markdown]
# And if we want a list of them?
# (This isn't a pandas thing, but is still super useful:)

# %%
# Gives all unique values
set(wine.loc[:, 'country'])
# Out:
# {'Albania',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Egypt',
#  'England',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'India',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Lebanon',
#  'Lithuania',
#  'Luxembourg',
#  'Macedonia',
#  'Mexico',
#  'Moldova',
#  'Montenegro',
#  'Morocco',
#  'New Zealand',
#  'Portugal',
#  'Romania',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Switzerland',
#  'Tunisia',
#  'Turkey',
#  'US',
#  'US-France',
#  'Ukraine',
#  'Uruguay',
#  nan}

# %% [markdown]
# You can look [here](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/) for a list of all the built-in pandas stats.

# %% [markdown]
# One of the most powerful built-in summary tools for pandas is `df.describe()`. This quickly calculates some of these stats for the numeric columns in the df.

# %% [markdown]
# **Question**: Why are only 2 of the columns included?

# %% [markdown]
# ### Conditional Selections
# We can use conditional selections to narrow our analysis even further.
#
# DON'T FORGET - to make things easier, we can save selections we plan to use often as their own variables.

# %%
us = wine[wine.loc[:, 'country']=="US"]
france = wine[wine.loc[:, 'country']=="France"]

# %%
print("Avg American wine price is: ", round(us.loc[:, 'price'].mean(), 2))
print("Avg Fremch wine price is: ", round(france.loc[:, 'price'].mean(), 2))
print("Avg Overall wine price is: ", round(wine.loc[:, 'price'].mean(), 2))
# Out:
# Avg American wine price is:  33.65
# Avg Fremch wine price is:  45.62
# Avg Overall wine price is:  33.13

# %% [markdown]
# We can then use these to calculate more targeted metrics.

# %%
avg_french_wine_price = round(france.loc[:, 'price'].mean(), 2)
avg_overall_wine_price = round(wine.loc[:, 'price'].mean(), 2)
price_difference = avg_french_wine_price = avg_overall_wine_price
print("French wine is ${} more expensive of average".format(round(price_difference)))
# Out:
# French wine is $33 more expensive of average

# %% [markdown]
# #### More advanced conditionals: Using masks
# When you want to filter on >1 criteria, it can be easier to use a mask.
#
# How many wines from North America do we have on our list?

# %%
# boolean mask for selecting counries in North Americaa
na_mask = ((wine.loc[:, 'country']=="US") 
           | (wine.loc[:, 'country']=="Mexico")
           | (wine.loc[:, 'country']=="Canada"))
na_indexes = wine.index[na_mask]

# selecting rows where vollean mask is True
na = wine.loc[na_indexes]

# %%
na = wine.loc[na_mask]

# %% [markdown]
# How many wines do we have total in the in North America?

# %%
na.isnull().any()
# Out:
# country        False
# description    False
# designation     True
# points         False
# price           True
# province       False
# region_1        True
# region_2        True
# variety        False
# winery         False
# dtype: bool

# %%
na.loc[:, "country"].count()
# Out:
# True

# %% [markdown]
# **Question:** How many of the wines belong to each country?
#
# **Question:** From which US state do most of our wines come?

# %%
na.isnull()
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0         False        False        False   False  False     False     False
# 2         False        False        False   False  False     False     False
# 3         False        False        False   False  False     False     False
# 8         False        False        False   False  False     False     False
# 9         False        False        False   False  False     False     False
# ...         ...          ...          ...     ...    ...       ...       ...
# 150892    False        False        False   False  False     False     False
# 150896    False        False         True   False  False     False     False
# 150914    False        False        False   False  False     False     False
# 150915    False        False        False   False  False     False     False
# 150916    False        False        False   False  False     False     False
#
#         region_2  variety  winery
# 0          False    False   False
# 2          False    False   False
# 3          False    False   False
# 8          False    False   False
# 9          False    False   False
# ...          ...      ...     ...
# 150892     False    False   False
# 150896     False    False   False
# 150914     False    False   False
# 150915     False    False   False
# 150916     False    False   False
#
# [62656 rows x 10 columns]

# %%
na.loc[:, 'country'].value_counts()
# Out:
# US        62397
# Canada      196
# Mexico       63
# Name: country, dtype: int64

# %%
us.loc[:, 'province'].value_counts()
# Out:
# California           44508
# Washington            9750
# Oregon                4589
# New York              2428
# Virginia               515
# Idaho                  136
# New Mexico              95
# Missouri                60
# Pennsylvania            50
# Texas                   41
# Arizona                 39
# Ohio                    34
# Colorado                30
# America                 27
# Michigan                25
# New Jersey              24
# North Carolina          20
# Massachusetts           10
# Iowa                     4
# Kentucky                 4
# Washington-Oregon        3
# Vermont                  2
# Connecticut              2
# Nevada                   1
# Name: province, dtype: int64

# %% [markdown]
# ## Groupby
# One of the most flexible ways to aggregate in pandas is with .groupby() .
# We will look at how this works for categorical datasets like this one, and also for datetime datasets, as dealing with datetimes in pandas can be tricky.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### How Groupby Works:
# You can group your data in many different ways, and also aggregate it by any of the aggregators we saw before: like mean, mode, sum, etc.

# %%
wine.groupby("country").mean().sort_values(by=['points', 'price'],
                                          ascending=False)
# Out:
#                            points      price
# country
# England                 92.888889  47.500000
# Austria                 89.276742  31.192106
# France                  88.925870  45.619885
# Germany                 88.626427  39.011078
# Italy                   88.413664  37.547913
# Canada                  88.239796  34.628866
# Slovenia                88.234043  28.061728
# Morocco                 88.166667  18.833333
# Turkey                  88.096154  25.800000
# Portugal                88.057685  26.332615
# US-France               88.000000  50.000000
# Albania                 88.000000  20.000000
# Australia               87.892475  31.258480
# US                      87.818789  33.653808
# Serbia                  87.714286  24.285714
# India                   87.625000  13.875000
# New Zealand             87.554217  24.173290
# Hungary                 87.329004  44.204348
# Switzerland             87.250000  26.500000
# South Africa            87.225421  21.130532
# Israel                  87.176190  31.304918
# Luxembourg              87.000000  40.666667
# Spain                   86.646589  27.048529
# Chile                   86.296768  19.344780
# Croatia                 86.280899  23.108434
# Greece                  86.117647  21.747706
# Tunisia                 86.000000        NaN
# Argentina               85.996093  20.794881
# Cyprus                  85.870968  15.483871
# Czech Republic          85.833333  18.000000
# Lebanon                 85.702703  25.432432
# Georgia                 85.511628  18.581395
# Bulgaria                85.467532  11.545455
# Japan                   85.000000  24.000000
# Romania                 84.920863  16.395683
# Macedonia               84.812500  15.312500
# Mexico                  84.761905  29.095238
# Bosnia and Herzegovina  84.750000  12.750000
# Moldova                 84.718310  15.366197
# Ukraine                 84.600000  13.000000
# Uruguay                 84.478261  25.847059
# Lithuania               84.250000  10.000000
# Slovakia                83.666667  15.333333
# Egypt                   83.666667        NaN
# Brazil                  83.240000  19.920000
# China                   82.000000  20.333333
# Montenegro              82.000000  10.000000
# South Korea             81.500000  13.500000

# %% [markdown]
# So, British wine is the highest average ranked?? This is surprising. Maybe we need to look at our data in a different way.

# %% [markdown]
# The beauty of `df.groupby()` is that it lets you aggregate different columns in different ways.
#
# Say we want to know the average price of wine in each country, but the _highest_ score:

# %%
wine.groupby("country").agg({"points": "max", "price": "mean"})\
    .sort_values(by=['points', 'price'], ascending=[False, True])
# Out:
#                         points      price
# country
# Australia                  100  31.258480
# US                         100  33.653808
# Italy                      100  37.547913
# France                     100  45.619885
# Portugal                    99  26.332615
# Spain                       98  27.048529
# Austria                     98  31.192106
# Argentina                   97  20.794881
# Germany                     97  39.011078
# Hungary                     96  44.204348
# Chile                       95  19.344780
# South Africa                95  21.130532
# New Zealand                 94  24.173290
# England                     94  47.500000
# Morocco                     93  18.833333
# Israel                      93  31.304918
# Canada                      93  34.628866
# Romania                     92  16.395683
# Georgia                     92  18.581395
# Greece                      92  21.747706
# Turkey                      92  25.800000
# Slovenia                    92  28.061728
# Mexico                      92  29.095238
# India                       91  13.875000
# Croatia                     91  23.108434
# Lebanon                     91  25.432432
# Bulgaria                    90  11.545455
# Moldova                     90  15.366197
# Uruguay                     90  25.847059
# Switzerland                 90  26.500000
# Macedonia                   89  15.312500
# Cyprus                      89  15.483871
# Serbia                      89  24.285714
# Bosnia and Herzegovina      88  12.750000
# Brazil                      88  19.920000
# Albania                     88  20.000000
# Luxembourg                  88  40.666667
# US-France                   88  50.000000
# Slovakia                    87  15.333333
# Czech Republic              87  18.000000
# Tunisia                     87        NaN
# Ukraine                     86  13.000000
# Lithuania                   85  10.000000
# Japan                       85  24.000000
# Egypt                       84        NaN
# Montenegro                  82  10.000000
# South Korea                 82  13.500000
# China                       82  20.333333

# %% [markdown]
# **Tip:** Sometimes, fo make your code cleaner it's best to move the aggregations out and store them in their own variable that you can update saparately.

# %%
aggs = {
    "price": "mean",
    "points": "max"
}

wine.groupby("country").agg(aggs).sort_values(by=["price", "points"], ascending=[False, True])
# Out:
#                             price  points
# country
# US-France               50.000000      88
# England                 47.500000      94
# France                  45.619885     100
# Hungary                 44.204348      96
# Luxembourg              40.666667      88
# Germany                 39.011078      97
# Italy                   37.547913     100
# Canada                  34.628866      93
# US                      33.653808     100
# Israel                  31.304918      93
# Australia               31.258480     100
# Austria                 31.192106      98
# Mexico                  29.095238      92
# Slovenia                28.061728      92
# Spain                   27.048529      98
# Switzerland             26.500000      90
# Portugal                26.332615      99
# Uruguay                 25.847059      90
# Turkey                  25.800000      92
# Lebanon                 25.432432      91
# Serbia                  24.285714      89
# New Zealand             24.173290      94
# Japan                   24.000000      85
# Croatia                 23.108434      91
# Greece                  21.747706      92
# South Africa            21.130532      95
# Argentina               20.794881      97
# China                   20.333333      82
# Albania                 20.000000      88
# Brazil                  19.920000      88
# Chile                   19.344780      95
# Morocco                 18.833333      93
# Georgia                 18.581395      92
# Czech Republic          18.000000      87
# Romania                 16.395683      92
# Cyprus                  15.483871      89
# Moldova                 15.366197      90
# Slovakia                15.333333      87
# Macedonia               15.312500      89
# India                   13.875000      91
# South Korea             13.500000      82
# Ukraine                 13.000000      86
# Bosnia and Herzegovina  12.750000      88
# Bulgaria                11.545455      90
# Montenegro              10.000000      82
# Lithuania               10.000000      85
# Egypt                         NaN      84
# Tunisia                       NaN      87

# %% [markdown]
# You can also use a list in your aggs to aggergate one column in different ways.
#
# This will give a **multi-index**. Multi-indexes can be difficult to sort on. But, there are a few different ways we can deal with this.

# %%
aggs = {
    "price": ["min", "mean", "max", "std"],
}
price_table = wine.groupby("country").agg(aggs)
price_table
# Out:
#                        price
#                          min       mean     max        std
# country
# Albania                 20.0  20.000000    20.0   0.000000
# Argentina                4.0  20.794881   250.0  20.186540
# Australia                5.0  31.258480   850.0  39.008512
# Austria                  8.0  31.192106  1100.0  28.540861
# Bosnia and Herzegovina  12.0  12.750000    13.0   0.500000
# Brazil                  11.0  19.920000    35.0   8.840814
# Bulgaria                 7.0  11.545455    28.0   4.959163
# Canada                  12.0  34.628866   145.0  24.267644
# Chile                    5.0  19.344780   400.0  19.618082
# China                    7.0  20.333333    27.0  11.547005
# Croatia                 12.0  23.108434    65.0  12.375243
# Cyprus                  10.0  15.483871    22.0   3.731586
# Czech Republic          15.0  18.000000    25.0   4.000000
# Egypt                    NaN        NaN     NaN        NaN
# England                 38.0  47.500000    75.0  11.964232
# France                   5.0  45.619885  2300.0  69.697060
# Georgia                  9.0  18.581395    40.0   8.990028
# Germany                  5.0  39.011078   775.0  56.857128
# Greece                   7.0  21.747706   120.0  12.273692
# Hungary                  7.0  44.204348   764.0  66.264502
# India                   10.0  13.875000    20.0   3.870677
# Israel                   8.0  31.304918   150.0  19.650363
# Italy                    5.0  37.547913   900.0  37.067869
# Japan                   24.0  24.000000    24.0   0.000000
# Lebanon                 12.0  25.432432    51.0  12.835585
# Lithuania               10.0  10.000000    10.0   0.000000
# Luxembourg              36.0  40.666667    50.0   7.000000
# Macedonia               12.0  15.312500    25.0   4.377499
# Mexico                  12.0  29.095238   108.0  16.938898
# Moldova                  8.0  15.366197    42.0   7.679731
# Montenegro              10.0  10.000000    10.0   0.000000
# Morocco                  6.0  18.833333    35.0   7.755741
# New Zealand              7.0  24.173290   125.0  13.569317
# Portugal                 4.0  26.332615   980.0  35.242873
# Romania                  4.0  16.395683   320.0  28.845571
# Serbia                  15.0  24.285714    42.0   9.335034
# Slovakia                15.0  15.333333    16.0   0.577350
# Slovenia                 7.0  28.061728    90.0  14.263017
# South Africa             5.0  21.130532   145.0  14.248025
# South Korea             11.0  13.500000    16.0   2.886751
# Spain                    4.0  27.048529   770.0  33.861666
# Switzerland             19.0  26.500000    38.0   8.582929
# Tunisia                  NaN        NaN     NaN        NaN
# Turkey                  14.0  25.800000   120.0  19.120456
# US                       4.0  33.653808  2013.0  24.891343
# US-France               50.0  50.000000    50.0        NaN
# Ukraine                 13.0  13.000000    13.0   0.000000
# Uruguay                  7.0  25.847059    60.0  15.066129

# %%
price_table.columns
# Out:
# MultiIndex([('price',  'min'),
#             ('price', 'mean'),
#             ('price',  'max'),
#             ('price',  'std')],
#            )

# %% [markdown]
# One way is by dropping the top level ('price'):

# %%
# price_table.columns = price_table.columns.droplevel(level=0)
price_table
# Out:
#                         m_i_n    m_e_a_n   m_a_x      s_t_d
# country
# Albania                  20.0  20.000000    20.0   0.000000
# Argentina                 4.0  20.794881   250.0  20.186540
# Australia                 5.0  31.258480   850.0  39.008512
# Austria                   8.0  31.192106  1100.0  28.540861
# Bosnia and Herzegovina   12.0  12.750000    13.0   0.500000
# Brazil                   11.0  19.920000    35.0   8.840814
# Bulgaria                  7.0  11.545455    28.0   4.959163
# Canada                   12.0  34.628866   145.0  24.267644
# Chile                     5.0  19.344780   400.0  19.618082
# China                     7.0  20.333333    27.0  11.547005
# Croatia                  12.0  23.108434    65.0  12.375243
# Cyprus                   10.0  15.483871    22.0   3.731586
# Czech Republic           15.0  18.000000    25.0   4.000000
# Egypt                     NaN        NaN     NaN        NaN
# England                  38.0  47.500000    75.0  11.964232
# France                    5.0  45.619885  2300.0  69.697060
# Georgia                   9.0  18.581395    40.0   8.990028
# Germany                   5.0  39.011078   775.0  56.857128
# Greece                    7.0  21.747706   120.0  12.273692
# Hungary                   7.0  44.204348   764.0  66.264502
# India                    10.0  13.875000    20.0   3.870677
# Israel                    8.0  31.304918   150.0  19.650363
# Italy                     5.0  37.547913   900.0  37.067869
# Japan                    24.0  24.000000    24.0   0.000000
# Lebanon                  12.0  25.432432    51.0  12.835585
# Lithuania                10.0  10.000000    10.0   0.000000
# Luxembourg               36.0  40.666667    50.0   7.000000
# Macedonia                12.0  15.312500    25.0   4.377499
# Mexico                   12.0  29.095238   108.0  16.938898
# Moldova                   8.0  15.366197    42.0   7.679731
# Montenegro               10.0  10.000000    10.0   0.000000
# Morocco                   6.0  18.833333    35.0   7.755741
# New Zealand               7.0  24.173290   125.0  13.569317
# Portugal                  4.0  26.332615   980.0  35.242873
# Romania                   4.0  16.395683   320.0  28.845571
# Serbia                   15.0  24.285714    42.0   9.335034
# Slovakia                 15.0  15.333333    16.0   0.577350
# Slovenia                  7.0  28.061728    90.0  14.263017
# South Africa              5.0  21.130532   145.0  14.248025
# South Korea              11.0  13.500000    16.0   2.886751
# Spain                     4.0  27.048529   770.0  33.861666
# Switzerland              19.0  26.500000    38.0   8.582929
# Tunisia                   NaN        NaN     NaN        NaN
# Turkey                   14.0  25.800000   120.0  19.120456
# US                        4.0  33.653808  2013.0  24.891343
# US-France                50.0  50.000000    50.0        NaN
# Ukraine                  13.0  13.000000    13.0   0.000000
# Uruguay                   7.0  25.847059    60.0  15.066129

# %%
price_table.columns = ["_".join(x) for x in price_table.columns.ravel()]
price_table.sort_values(by='price_mean', ascending=False).head()
# Out:
#             price_min  price_mean  price_max  price_std
# country
# US-France        50.0   50.000000       50.0        NaN
# England          38.0   47.500000       75.0  11.964232
# France            5.0   45.619885     2300.0  69.697060
# Hungary           7.0   44.204348      764.0  66.264502
# Luxembourg       36.0   40.666667       50.0   7.000000

# %%
price_table.columns
# Out:
# Index(['price_min', 'price_mean', 'price_max', 'price_std'], dtype='object')

# %% [markdown]
# Another way is by using `np.ravel()` . This preserves the "price" indicator somewhere in each of the column names.

# %% [markdown]
# **Question**: Create a quick plot of the number of wines made in each country, from highest to lowest.

# %%
wine['country'].value_counts().plot(kind='bar', figsize=(10, 7))
plt.show()

# %% [markdown]
# ## Selecting the max and min values with Index Max and Min
# In addition to `.max()` and `.min()`, which returns the maximum or minimum values, we can use `.idxmax()` and `.idxmin()` to return the *index* pertaining to the maximum and minimum values.
#
# For example, let's use `.idxmax()` to find the country with the highest standard deviation in its prices.

# %%
price_table
# Out:
#                         price_min  price_mean  price_max  price_std
# country
# Albania                      20.0   20.000000       20.0   0.000000
# Argentina                     4.0   20.794881      250.0  20.186540
# Australia                     5.0   31.258480      850.0  39.008512
# Austria                       8.0   31.192106     1100.0  28.540861
# Bosnia and Herzegovina       12.0   12.750000       13.0   0.500000
# Brazil                       11.0   19.920000       35.0   8.840814
# Bulgaria                      7.0   11.545455       28.0   4.959163
# Canada                       12.0   34.628866      145.0  24.267644
# Chile                         5.0   19.344780      400.0  19.618082
# China                         7.0   20.333333       27.0  11.547005
# Croatia                      12.0   23.108434       65.0  12.375243
# Cyprus                       10.0   15.483871       22.0   3.731586
# Czech Republic               15.0   18.000000       25.0   4.000000
# Egypt                         NaN         NaN        NaN        NaN
# England                      38.0   47.500000       75.0  11.964232
# France                        5.0   45.619885     2300.0  69.697060
# Georgia                       9.0   18.581395       40.0   8.990028
# Germany                       5.0   39.011078      775.0  56.857128
# Greece                        7.0   21.747706      120.0  12.273692
# Hungary                       7.0   44.204348      764.0  66.264502
# India                        10.0   13.875000       20.0   3.870677
# Israel                        8.0   31.304918      150.0  19.650363
# Italy                         5.0   37.547913      900.0  37.067869
# Japan                        24.0   24.000000       24.0   0.000000
# Lebanon                      12.0   25.432432       51.0  12.835585
# Lithuania                    10.0   10.000000       10.0   0.000000
# Luxembourg                   36.0   40.666667       50.0   7.000000
# Macedonia                    12.0   15.312500       25.0   4.377499
# Mexico                       12.0   29.095238      108.0  16.938898
# Moldova                       8.0   15.366197       42.0   7.679731
# Montenegro                   10.0   10.000000       10.0   0.000000
# Morocco                       6.0   18.833333       35.0   7.755741
# New Zealand                   7.0   24.173290      125.0  13.569317
# Portugal                      4.0   26.332615      980.0  35.242873
# Romania                       4.0   16.395683      320.0  28.845571
# Serbia                       15.0   24.285714       42.0   9.335034
# Slovakia                     15.0   15.333333       16.0   0.577350
# Slovenia                      7.0   28.061728       90.0  14.263017
# South Africa                  5.0   21.130532      145.0  14.248025
# South Korea                  11.0   13.500000       16.0   2.886751
# Spain                         4.0   27.048529      770.0  33.861666
# Switzerland                  19.0   26.500000       38.0   8.582929
# Tunisia                       NaN         NaN        NaN        NaN
# Turkey                       14.0   25.800000      120.0  19.120456
# US                            4.0   33.653808     2013.0  24.891343
# US-France                    50.0   50.000000       50.0        NaN
# Ukraine                      13.0   13.000000       13.0   0.000000
# Uruguay                       7.0   25.847059       60.0  15.066129

# %%
price_table.loc[:, 'price_min'].idxmin()
# Out:
# 'Argentina'

# %%
# Exercise
# Find the country with the highest average price

wine.groupby("country").mean().loc[:,"price"].idxmax()
# Out:
# 'US-France'

# %%
price_table.loc[:, 'price_mean'].max()
# Out:
# 50.0

# %% [markdown]
# # Dealing with datetime in Pandas
# Pandas built off the datetime package in Python to offer a datetime index, and plenty of ways to work with this.
# However, it is still far from intuitive.
# That doesn't mean it's not useful, and for anyone doing a timeseries project, you'll need to deal with dates and times in pandas often.
#
# Let's load a sample dataset of datetime energy data and get started!

# %%
energy = pd.read_csv('data/energy/PJM_Load_hourly.csv', parse_dates=True, index_col=0)

# %% [markdown]
# Note that this data has a DateTimeIndex.
# setting `parse_dates=True` when we read the CSV lets pandas infer this datetimeindex.

# %%
energy.index
# Out:
# DatetimeIndex(['1998-12-31 01:00:00', '1998-12-31 02:00:00',
#                '1998-12-31 03:00:00', '1998-12-31 04:00:00',
#                '1998-12-31 05:00:00', '1998-12-31 06:00:00',
#                '1998-12-31 07:00:00', '1998-12-31 08:00:00',
#                '1998-12-31 09:00:00', '1998-12-31 10:00:00',
#                ...
#                '2001-01-01 15:00:00', '2001-01-01 16:00:00',
#                '2001-01-01 17:00:00', '2001-01-01 18:00:00',
#                '2001-01-01 19:00:00', '2001-01-01 20:00:00',
#                '2001-01-01 21:00:00', '2001-01-01 22:00:00',
#                '2001-01-01 23:00:00', '2001-01-02 00:00:00'],
#               dtype='datetime64[ns]', name='Datetime', length=32896, freq=None)

# %% [markdown]
# We can select data points within a specific time range, using the DateTimeIndex and .loc.
# Here, we select the first one day of data.

# %%
# One record for each hour of this day.
energy.loc['1998-12-31 01:00:00': '1999-01-01 02:00:00'].shape[0]
# Out:
# 26

# %% [markdown]
# ## Selecting with boolean indexing on pandas datetimeindex
# We can use .dot notation with conditionals to select on specific parts of the datetime, like days or months.

# %% [markdown]
# Python datetime functionality example:

# %%
from datetime import datetime

s = "8 March, 2017"
d = datetime.strptime(s, "%d %B, %Y")
new_s = d.strftime("%Y-%m-%d")
new_s
# Out:
# '2017-03-08'

# %%
d
# Out:
# datetime.datetime(2017, 3, 8, 0, 0)

# %%
# making a new DF that only includes the month of septmeber from each year.
septembers = energy.loc[energy.index.month == 9]
septembers
# Out:
#                      PJM_Load_MW
# Datetime
# 1998-09-30 01:00:00      22127.0
# 1998-09-30 02:00:00      21028.0
# 1998-09-30 03:00:00      20339.0
# 1998-09-30 04:00:00      20295.0
# 1998-09-30 05:00:00      20548.0
# ...                          ...
# 2001-09-01 21:00:00      31687.0
# 2001-09-01 22:00:00      30174.0
# 2001-09-01 23:00:00      28026.0
# 2001-09-02 00:00:00      25711.0
# 2001-09-01 00:00:00      33489.0
#
# [2880 rows x 1 columns]

# %% [markdown]
# We can also call just a date, and get all the hours/time periods in that day:

# %% [markdown]
# Same with for a year and month:

# %%
28 * 24
# Out:
# 672

# %%
# We see that it includes one record for each our of each day of the month of January, which has 31 days

# %%
# or better, with an assert statement:

# %% [markdown]
# ## Resampling
# We can also combine the data in different ways, and over different time periods.
# This means that just because our data is in hourly time periods, we dont have to keep it that way.

# %%
# We can get the average load over a day:
daily_avg_energy = energy.resample("D").mean()
daily_avg_energy.head()
# Out:
#              PJM_Load_MW
# Datetime
# 1998-04-01  27813.739130
# 1998-04-02  26605.791667
# 1998-04-03  25672.333333
# 1998-04-04  24487.083333
# 1998-04-05  23487.565217

# %%
# We can also get the total MWh used in a day:
daily_energy = energy.resample("D").sum()
daily_energy.columns = ['PJM_Load_MWh']
daily_energy.head()
# Out:
#             PJM_Load_MWh
# Datetime
# 1998-04-01      639716.0
# 1998-04-02      638539.0
# 1998-04-03      616136.0
# 1998-04-04      587690.0
# 1998-04-05      540214.0

# %% [markdown]
# ## Groupby with DateTimeIndex
# Using groupby with a pandas DateTimeIndex can be extremely useful and powerful.
# Let's look at how this can work.

# %%
indexes = [energy.index.year,
          energy.index.month,
          energy.index.week,
          energy.index.weekday,
          energy.index.day]

aggregated = energy.groupby(indexes).sum()

# %%
aggregated.index.set_names("year", level=0, inplace=True)
aggregated.index.set_names("month", level=1, inplace=True)
aggregated.index.set_names("week", level=2, inplace=True)
aggregated.index.set_names("weekday", level=3, inplace=True)
aggregated.index.set_names("day", level=4, inplace=True)

# %%
index_level_names = ['year', 'month', 'week', 'weekday', 'day']
for i, index_level in enumerate(index_level_names):
    aggregated.index.set_names(index_level, level=i, inplace=True)

# %%
aggregated.head()
# Out:
#                              PJM_Load_MW
# year month week weekday day
# 1998 4     14   2       1       639716.0
#                 3       2       638539.0
#                 4       3       616136.0
#                 5       4       587690.0
#                 6       5       540214.0

# %% [markdown]
# The index level names are not particularly helpful here. We can change them.

# %%
# the long, ugly way

# %%
# the short, clean way. Both do the same thing.

# %% [markdown]
# ### Selecting on Multi-Index: Using Slice

# %%
energy_2000 = aggregated.loc[(slice(2000,2000),
                            slice(None),
                            slice(None),
                            slice(None),
                            slice(None)),:]
energy_2000
# Out:
#                              PJM_Load_MW
# year month week weekday day
# 2000 1     1    0       3       656411.0
#                 1       4       679531.0
#                 2       5       735085.0
#                 3       6       770492.0
#                 4       7       742633.0
# ...                                  ...
#      12    52   2       27      841897.0
#                 3       28      843363.0
#                 4       29      840427.0
#                 5       30      780665.0
#                 6       31      755509.0
#
# [366 rows x 1 columns]

# %%
aggregated.reset_index(inplace=True)

# %% [markdown]
# Or, say we want to know what Christmas week looked like across all the years for which we have data..

# %% [markdown]
# You can also then use a groupby again!
#
# Note that here, we're using a groupby on the index level.

# %% [markdown]
# Now, we can plot by these levels!

# %% [markdown]
# **Question:** See what just writing "52" in the slice box does.

# %% [markdown]
# **Question**: Select Christmas week, but only for years 1998-2000.

# %%
date_mask = ((aggregated.loc[:, 'week'] == 52) & (aggregated.loc[:,"year"] < 2001))
aggregated.loc[date_mask]
# Out:
#       index  year  month  week  weekday  day  PJM_Load_MW
# 264     264  1998     12    52        0   21     687525.0
# 265     265  1998     12    52        1   22     709706.0
# 266     266  1998     12    52        2   23     804521.0
# 267     267  1998     12    52        3   24     731226.0
# 268     268  1998     12    52        4   25     654678.0
# 269     269  1998     12    52        5   26     705061.0
# 270     270  1998     12    52        6   27     676417.0
# 635     635  1999     12    52        0   27     759579.0
# 636     636  1999     12    52        1   28     786960.0
# 637     637  1999     12    52        2   29     772803.0
# 638     638  1999     12    52        3   30     720254.0
# 639     639  1999     12    52        4   31     652799.0
# 669     669  2000      1    52        5    1     629453.0
# 670     670  2000      1    52        6    2     593973.0
# 999     999  2000     12    52        0   25     764130.0
# 1000   1000  2000     12    52        1   26     834687.0
# 1001   1001  2000     12    52        2   27     841897.0
# 1002   1002  2000     12    52        3   28     843363.0
# 1003   1003  2000     12    52        4   29     840427.0
# 1004   1004  2000     12    52        5   30     780665.0
# 1005   1005  2000     12    52        6   31     755509.0

# %% [markdown]
# **Question**: Which week is christmas in all of the years?

# %% [markdown]
# ## Selecting on Multi-Index: Using reset_index()
# The `slice` method in pandas can be difficult to work with and read. Often times, it can be easier to work with these as "normal" pandas DataFrame columns.
#
# As an example, we'll select the Christmas week the same way we did with the slice command above.

# %% [markdown]
# ## Exercise:
# - Find the week (and its associated year) with the highest total weekly consumption.
#
# - Find the day of the week that averages the highest consumption
#
# - Find the time of day that averages the lowest consumption.
#     - Has this changed over the years?
#
#
# - Is average consumption rising, falling, or staying the same over the years?
# - What is the %age difference in consumption on average between April and June?

# %% [markdown]
# - Find the week (and its associated year) with the highest total weekly consumption.

# %% [markdown]
# - Find the day of the week that averages the highest consumption

# %% [markdown]
# - Find the time of day that averages the lowest consumption.
#     - Has this changed over the years?

# %% [markdown]
# - Is average consumption rising, falling, or staying the same over the years?

# %% [markdown]
# - What is the %age difference in consumption on average between April and June?
